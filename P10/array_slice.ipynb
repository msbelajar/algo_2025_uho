# %%
import numpy as np

# %%
x = np.array([3, -2, 5, -1, 2, 6, 0.5, -100])
x
# Out:
# array([   3. ,   -2. ,    5. ,   -1. ,    2. ,    6. ,    0.5, -100. ])

# %%
#unsur pertama x
x[0]
# Out:
# np.float64(3.0)

# %%
#unsur kedua x
x[1]
# Out:
# np.float64(-2.0)

# %%
#unsur pertama dari belakang
x[-1]
# Out:
# np.float64(-100.0)

# %%
#unsur ke 6 (5+1) hingga terakhir
x[5:]
# Out:
# array([   6. ,    0.5, -100. ])

# %%
#5 unsur pertama
x[:5]
# Out:
# array([ 3., -2.,  5., -1.,  2.])

# %%
x
# Out:
# array([   3. ,   -2. ,    5. ,   -1. ,    2. ,    6. ,    0.5, -100. ])

# %%
#index 1 hingga 4 (5-1)
x[1:5]
# Out:
# array([-2.,  5., -1.,  2.])
