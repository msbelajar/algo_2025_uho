# %% [markdown]
# ### Himpunan

# %%
A = {1,3,4}
B = {1,2,5}
gabungan = A | B
gabungan
# Out:
# {1, 2, 3, 4, 5}

# %%
A = {1,3,5,8}
B = {3,5,10}
irisan = A & B
irisan
# Out:
# {3, 5}

# %%
A = {1,3,5,7}
B = {3,5,10,11}
selisihAB = A - B
selisihAB
# Out:
# {1, 7}

# %%
B - A
# Out:
# {10, 11}

# %%
A = {1,3,5,7,9}
B = {1,5,9,11,13}
bedasimetri = A ^ B
bedasimetri
# Out:
# {3, 7, 11, 13}
