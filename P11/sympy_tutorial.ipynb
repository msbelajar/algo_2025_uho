# %%
from sympy import *

# %%
x = Symbol('x')
f = (2*x + 3)**3
f
# Out:
# (2*x + 3)**3

# %%
expand(f)
# Out:
# 8*x**3 + 36*x**2 + 54*x + 27

# %%
y = Symbol('y')
h = x**2 + y**2 + 2*x + 3*y - 100
h
# Out:
# x**2 + 2*x + y**2 + 3*y - 100

# %%
a,b,c = symbols('a b c')
a**2 + b**2 - c**2
# Out:
# a**2 + b**2 - c**2

# %%
f = x**2 - 3*x + 1
f
# Out:
# x**2 - 3*x + 1

# %%
f.subs(x,0)
# Out:
# 1

# %%
#Limit
f = (x**2 - 1) / (x - 1)
limit(f, x, 1)
# Out:
# 2

# %%
#Turunan
diff(f, x)
# Out:
# 2*x/(x - 1) - (x**2 - 1)/(x - 1)**2

# %%
#Turunan Parsial
F = x*y**2 - 2*x + 3*y
F
# Out:
# x*y**2 - 2*x + 3*y

# %%
diff(F, x)
# Out:
# y**2 - 2

# %%
diff(F, y)
# Out:
# 2*x*y + 3

# %%
#Integral
f = x**2 + x - 1
f
# Out:
# x**2 + x - 1

# %%
integrate(f, x)
# Out:
# x**3/3 + x**2/2 - x

# %%
Integral(f,x)
# Out:
# Integral(x**2 + x - 1, x)

# %%
integrate(f, (x,0,1))
# Out:
# -1/6

# %%
Integral(f,(x,0,1))
# Out:
# Integral(x**2 + x - 1, (x, 0, 1))

# %%
#integral tak wajar
Integral(1/x**2, (x,1,oo))
# Out:
# Integral(x**(-2), (x, 1, oo))

# %%
integrate(1/x**2, (x,1,oo))
# Out:
# 1

# %%
f = x + 3
solve(f,x)
# Out:
# [-3]

# %%
f1 = x + y - 3
f2 = 2*x + 3*y - 8
solve([f1, f2], [x,y])
# Out:
# {x: 1, y: 2}
