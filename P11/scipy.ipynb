# %%
from scipy import constants

# %%
#konstanta
pi = constants.pi
pi
# Out:
# 3.141592653589793

# %%
bilanganAvogrado = constants.Avogadro
bilanganAvogrado
# Out:
# 6.02214076e+23

# %%
from scipy.integrate import quad

def integrand(x, a, b):
    return a*x**2 + b

a = 2
b = 1
I = quad(integrand, 0, 1, args=(a,b))
I
# Out:
# (1.6666666666666667, 1.8503717077085944e-14)

# %%
from scipy import * #import semua
import numpy as np

# %%
A = np.array([[1,0], [3,1]])
A
# Out:
# array([[1, 0],
#        [3, 1]])

# %%
linalg.det(A)
# Out:
# np.float64(1.0)

# %%
linalg.inv(A)
# Out:
# array([[ 1.,  0.],
#        [-3.,  1.]])

# %%
linalg.eig(A)
# Out:
# (array([1.+0.j, 1.+0.j]),
#  array([[ 0.00000000e+00,  7.40148683e-17],
#         [ 1.00000000e+00, -1.00000000e+00]]))
