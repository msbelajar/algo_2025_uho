# %% [markdown]
# ### Referensi Markdown

# %% [markdown]
# - Markdown Live [markdownlivepreview.com](https://markdownlivepreview.com/)
# - Markdown Cheatsheet [markdownguide.org](https://www.markdownguide.org/cheat-sheet/)

# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3
# #### Heading 4

# %% [markdown]
# 1. First item
# 2. Second item
# 3. Third item

# %% [markdown]
# - First item
# - Second item
# - Third item
