# %%
A = [89, 45, 68, 90, 29, 34, 17]
A
# Out:
# [89, 45, 68, 90, 29, 34, 17]

# %%
# mengecek suatu elemen ada dalam list
100 in A
# Out:
# False

# %%
17 in A
# Out:
# True

# %%
# panjang dari suatu list
B = [4, 5, 4, 7, 8, 9]
len(B)
# Out:
# 6

# %%
# menukar nilai
a = 2
b = 5
print(f"a = {a} dan b = {b}")
c = a
a = b
b = c
print(f"a = {a} dan b = {b}")
# Out:
# a = 2 dan b = 5
# a = 5 dan b = 2

# %%
#cara cepat menukar nilai
a = 2
b = 5
print(f"a = {a} dan b = {b}")
a,b = b,a
print(f"a = {a} dan b = {b}")
# Out:
# a = 2 dan b = 5
# a = 5 dan b = 2

# %%
#range
for i in range(9): # 0 sampai 8
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
for i in range(2,9): #2 sampai 8
    print(i)
# Out:
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
for i in range(2,10,2): #mulai dari 2, tambah 2 dari elemen sebelumnya, hingga <10
    print(i)
# Out:
# 2
# 4
# 6
# 8

# %%
A = 10
A
# Out:
# 10

# %%
A + 10
# Out:
# 20

# %%
A = 5
A
# Out:
# 5
